# %%
# Import Dependencies
import pandas as pd
from pathlib import Path

# %%
# Store filepaths into variable
first_look = Path("Resources/ACSST1Y2022.S2701-2024-01-26T033804.csv")

# %%
# Read in files.
first_look_df = pd.read_csv(first_look)
first_look_df.head()
# Out:
#                            Label (Grouping) Alabama!!Total!!Estimate  \
# 0  Civilian noninstitutionalized population                4,988,625
# 1                                       AGE                      NaN
# 2                             Under 6 years                  345,530
# 3                             6 to 18 years                  837,133
# 4                            19 to 25 years                  467,350
#
#   Alabama!!Total!!Margin of Error Alabama!!Insured!!Estimate  \
# 0                          ±2,393                  4,551,357
# 1                             NaN                        NaN
# 2                          ±5,755                    337,813
# 3                          ±7,868                    807,622
# 4                          ±7,660                    391,938
#
#   Alabama!!Insured!!Margin of Error Alabama!!Percent Insured!!Estimate  \
# 0                           ±16,987                              91.2%
# ...

# %%
first_look_df.columns
# Out:
# Index(['Label (Grouping)', 'Alabama!!Total!!Estimate',
#        'Alabama!!Total!!Margin of Error', 'Alabama!!Insured!!Estimate',
#        'Alabama!!Insured!!Margin of Error',
#        'Alabama!!Percent Insured!!Estimate',
#        'Alabama!!Percent Insured!!Margin of Error',
#        'Alabama!!Uninsured!!Estimate', 'Alabama!!Uninsured!!Margin of Error',
#        'Alabama!!Percent Uninsured!!Estimate',
#        ...
#        'Puerto Rico!!Total!!Estimate', 'Puerto Rico!!Total!!Margin of Error',
#        'Puerto Rico!!Insured!!Estimate',
#        'Puerto Rico!!Insured!!Margin of Error',
#        'Puerto Rico!!Percent Insured!!Estimate',
#        'Puerto Rico!!Percent Insured!!Margin of Error',
#        'Puerto Rico!!Uninsured!!Estimate',
#        'Puerto Rico!!Uninsured!!Margin of Error',
#        'Puerto Rico!!Percent Uninsured!!Estimate',
#        'Puerto Rico!!Percent Uninsured!!Margin of Error'],
#       dtype='object', length=521)
